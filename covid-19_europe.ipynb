# %%
import numpy as np
import pandas as pd

from datetime import date, timedelta

from bokeh.layouts import layout, column, row
from bokeh.models import ColumnDataSource, Slider, Button
from bokeh.plotting import figure
from bokeh.io import show, output_notebook, curdoc

from data_loader import load_data

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1166">Loading BokehJS ...</span>
#     </div>

# %%
def app(doc):
    all_data = load_data()
    source = ColumnDataSource(all_data)
    
    chloropleth = figure()
    cases = figure()
    tests = figure()
    
    # chloropleth.patches('x', 'y', fill_alpha=0.7, fill_color='white', line_color={obj with transform}, line_width=0.5, source=geo_source)
    # cases.line()
    # tests.line()
    
    def slider_update(attrname, old, new):
        # update the slider
        pass
    
    slider = Slider(start=0, end=10, value=0, step=1, title="Date")
    slider.on_change('value', slider_update)
    
    def animate_update():
        # update the values
        pass
    
    def animate():
        # go from day to day
        pass
    
    button = Button(label='► Play', width=60)
    button.on_click(animate)
    
    tools = column(button, slider)
    layout = row(
        column(chloropleth, tools),
        cases,
        tests)
    
    doc.add_root(layout)

# %%
show(app)
# Out:
# <script id="1164">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:42313/autoload.js?bokeh-autoload-element=1164&bokeh-absolute-url=http://localhost:42313&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=1164&bokeh-absolute-url=http://localhost:42313&resources=none (127.0.0.1)
# HTTPServerRequest(protocol='http', host='localhost:42313', method='GET', uri='/autoload.js?bokeh-autoload-element=1164&bokeh-absolute-url=http://localhost:42313&resources=none', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
# ...
